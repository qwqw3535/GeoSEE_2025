# %%
import pandas as pd

# %%
df = pd.read_csv("/home/donggyu/RegionalEstimationLLM/extracted_paragraphs/v4_merged/landuse_added/PL_SK_CZ_HU_GRDP_HU_adm2_9549_paragraph_output.csv")

# %%
df['len'] = df['desc'].apply(lambda x: len(x.split('\n')))
df['len'].value_counts()
# Out:
# len
# 10    115
# Name: count, dtype: int64
