# %%
import pandas as pd

# %%
ccode = 'SK'

# %%
df1 = pd.read_csv(f"/home/donggyu/RegionalEstimationLLM/data/label/{ccode}_GRDP.csv")
df2 = pd.read_csv(f"/home/donggyu/RegionalEstimationLLM/data/label/{ccode}_ELP.csv")

# %%
df2['area_name'] = df1['area_name']
df2['area_id'] = df1['area_id']

# %%
df2= df2.dropna()

# %%
df2['ELP'] = df2['ELP'].apply(lambda x: int(x.replace(',', '')))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_108807/4075088102.py in <cell line: 1>()
# ----> 1 df2['ELP'] = df2['ELP'].apply(lambda x: int(x.replace(',', '')))
#
# ~/anaconda3/envs/rellm2/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4915         dtype: float64
#    4916         """
# -> 4917         return SeriesApply(
#    4918             self,
#    4919             func,
#
# ~/anaconda3/envs/rellm2/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# ~/anaconda3/envs/rellm2/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
# ...

# %%
df2.to_csv(f"/home/donggyu/RegionalEstimationLLM/data/label/{ccode}_ELP.csv",index=False)
